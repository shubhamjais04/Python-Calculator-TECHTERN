# %% [markdown]
# # Day 6 - Calculator Project
#
# Intern: Shubham Jaiswal
# Company: TECHTERN
# Date: 14-March-2026
# Topic: Calculator Project using Python Functions

# %% [markdown]
# ## About the Project
# In this project I have made a calculator using Python.
# It can perform basic operations like addition, subtraction,
# multiplication and division as well as some advanced operations
# like square root, power and modulus.

# %% [markdown]
# ## Basic Operations
# First I will define simple functions for basic calculations.

# %%
# addition
def add(a, b):
    return a + b

# subtraction
def subtract(a, b):
    return a - b

# multiplication
def multiply(a, b):
    return a * b

# division
def divide(a, b):
    if b == 0:
        return "error: cannot divide by zero"
    return a / b

# %%
# testing basic operations
print("addition:", add(10, 5))
print("subtraction:", subtract(10, 5))
print("multiplication:", multiply(10, 5))
print("division:", divide(10, 5))
# Out:
# addition: 15
# subtraction: 5
# multiplication: 50
# division: 2.0

# %%
# testing divide by zero
print(divide(10, 0))
# Out:
# error: cannot divide by zero

# %% [markdown]
# ## Advanced Operations
# Now I will add some advanced functions to the calculator.

# %%
import math

# square root
def square_root(a):
    if a < 0:
        return "error: cannot find square root of negative number"
    return math.sqrt(a)

# power
def power(a, b):
    return a ** b

# modulus
def modulus(a, b):
    return a % b

# square
def square(a):
    return a * a

# %%
# testing advanced operations
print("square root of 25:", square_root(25))
print("square root of 16:", square_root(16))
print("2 to the power 5:", power(2, 5))
print("modulus 10 % 3:", modulus(10, 3))
print("square of 6:", square(6))
# Out:
# square root of 25: 5.0
# square root of 16: 4.0
# 2 to the power 5: 32
# modulus 10 % 3: 1
# square of 6: 36

# %%
# testing square root of negative number
print(square_root(-4))
# Out:
# error: cannot find square root of negative number

# %% [markdown]
# ## Main Calculator
# Now I will combine all functions into one main calculator
# that takes input from the user and shows the result.

# %%
def calculator():
    print("========Welcome to Calculator=======")
    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")
    print("5. Square Root")
    print("6. Power")
    print("7. Modulus")
    print("8. Square")
    print("=====================================")

    choice = int(input("enter your choice (1-8): "))

    if choice in [1,2,3,4,6,7]:
        a = float(input("enter first number: "))
        b = float(input("enter second number: "))
    elif choice in [5,8]:
        a= float(input("enter number: "))

    if choice == 1:
        print("result = ", add(a, b))
    elif choice == 2:
        print("result = ", subtract(a, b))
    elif choice == 3:
        print("result =", multiply(a, b))
    elif choice == 4:
        print("result =", divide(a, b))
    elif choice == 5:
        print("result =", square_root(a))
    elif choice == 6:
        print("result =", power(a, b))
    elif choice == 7:
        print("result =", modulus(a, b))
    elif choice == 8:
        print("result =", square(a))
    else:
        print("invalid choice")

calculator()
# Out:
# ========Welcome to Calculator=======
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Square Root
# 6. Power
# 7. Modulus
# 8. Square
# ...
# enter your choice (1-8):  4
# enter first number:  6
# enter second number:  2
# result = 3.0

# %% [markdown]
# ## Testing the Calculator
# Lets test all the operations one by one.

# %%
# testing all functions together
print("===== Testing All Operations =====")
print("10 + 5 =", add(10, 5))
print("10 - 5 =", subtract(10, 5))
print("10 * 5 =", multiply(10, 5))
print("10 / 5 =", divide(10, 5))
print("square root of 49 =", square_root(49))
print("3 to the power 4 =", power(3, 4))
print("10 % 3 =", modulus(10, 3))
print("square of 9 =", square(9))
# Out:
# ===== Testing All Operations =====
# 10 + 5 = 15
# 10 - 5 = 5
# 10 * 5 = 50
# 10 / 5 = 2.0
# square root of 49 = 7.0
# 3 to the power 4 = 81
# 10 % 3 = 1
# square of 9 = 81

# %% [markdown]
# ## Summary
# In this project I made an advanced calculator using Python.
# I used functions to keep the code clean and organized.
# The calculator can perform 8 different operations including
# basic and advanced calculations.
#
# This project helped me understand how functions work
# in a real project.
